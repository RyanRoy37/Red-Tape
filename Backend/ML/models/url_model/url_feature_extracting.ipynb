# %%
import pandas as pd

# %%
# !python -m wget http://data.phishtank.com/data/online-valid.csv
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\jryan\Documents\Red-Tape\red_tape_env\Lib\site-packages\wget.py", line 568, in <module>
#     filename = download(args[0], out=options.output)
#   File "c:\Users\jryan\Documents\Red-Tape\red_tape_env\Lib\site-packages\wget.py", line 526, in download
#     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#                          ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py", line 214, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#                             ~~~~~~~^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py", line 189, in urlopen
# ...

# %%
dataset_1=pd.read_csv("C:/Users/jryan/Documents/Red-Tape/Backend/ML/data/All.csv")

# %%
dataset_1.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 5                5.5
# 1            0                   4                 5                5.5
# 2            0                   4                 5                5.5
# 3            0                   4                12                5.5
# 4            0                   4                 6                5.5
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                  14         4.400000    4               8            3
# 1                  14         6.000000    4              12            4
# 2                  14         5.800000    4              12            5
# 3                  14         5.500000    4              32           16
# 4                  14         7.333334    4              18           11
#
#    ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# ...

# %%
dataset_1.columns
# Out:
# Index(['Querylength', 'domain_token_count', 'path_token_count',
#        'avgdomaintokenlen', 'longdomaintokenlen', 'avgpathtokenlen', 'tld',
#        'charcompvowels', 'charcompace', 'ldl_url', 'ldl_domain', 'ldl_path',
#        'ldl_filename', 'ldl_getArg', 'dld_url', 'dld_domain', 'dld_path',
#        'dld_filename', 'dld_getArg', 'urlLen', 'domainlength', 'pathLength',
#        'subDirLen', 'fileNameLen', 'this.fileExtLen', 'ArgLen', 'pathurlRatio',
#        'ArgUrlRatio', 'argDomanRatio', 'domainUrlRatio', 'pathDomainRatio',
#        'argPathRatio', 'executable', 'isPortEighty', 'NumberofDotsinURL',
#        'ISIpAddressInDomainName', 'CharacterContinuityRate',
#        'LongestVariableValue', 'URL_DigitCount', 'host_DigitCount',
#        'Directory_DigitCount', 'File_name_DigitCount', 'Extension_DigitCount',
#        'Query_DigitCount', 'URL_Letter_Count', 'host_letter_count',
#        'Directory_LetterCount', 'Filename_LetterCount',
# ...

# %% [markdown]
# Index(['Querylength', 'domain_token_count', 'path_token_count',
#        'avgdomaintokenlen', 'longdomaintokenlen', 'avgpathtokenlen', 'tld',
#        'charcompvowels', 'charcompace', 'ldl_url', 'ldl_domain', 'ldl_path',
#        'ldl_filename', 'ldl_getArg', 'dld_url', 'dld_domain', 'dld_path',
#        'dld_filename', 'dld_getArg', 'urlLen', 'domainlength', 'pathLength',
#        'subDirLen', 'fileNameLen', 'this.fileExtLen', 'ArgLen', 'pathurlRatio',
#        'ArgUrlRatio', 'argDomanRatio', 'domainUrlRatio', 'pathDomainRatio',
#        'argPathRatio', 'executable', 'isPortEighty', 'NumberofDotsinURL',
#        'ISIpAddressInDomainName', 'CharacterContinuityRate',
#        'LongestVariableValue', 'URL_DigitCount', 'host_DigitCount',
#        'Directory_DigitCount', 'File_name_DigitCount', 'Extension_DigitCount',
#        'Query_DigitCount', 'URL_Letter_Count', 'host_letter_count',
#        'Directory_LetterCount', 'Filename_LetterCount',
#        'Extension_LetterCount', 'Query_LetterCount', 'LongestPathTokenLength',
#        'Domain_LongestWordLength', 'Path_LongestWordLength',
#        'sub-Directory_LongestWordLength', 'Arguments_LongestWordLength',
#        'URL_sensitiveWord', 'URLQueries_variable', 'spcharUrl',
#        'delimeter_Domain', 'delimeter_path', 'delimeter_Count',
#        'NumberRate_URL', 'NumberRate_Domain', 'NumberRate_DirectoryName',
#        'NumberRate_FileName', 'NumberRate_Extension', 'NumberRate_AfterPath',
#        'SymbolCount_URL', 'SymbolCount_Domain', 'SymbolCount_Directoryname',
#        'SymbolCount_FileName', 'SymbolCount_Extension',
#        'SymbolCount_Afterpath', 'Entropy_URL', 'Entropy_Domain',
#        'Entropy_DirectoryName', 'Entropy_Filename', 'Entropy_Extension',
#        'Entropy_Afterpath', 'URL_Type_obf_Type'],
#       dtype='object')

# %%
dataset_1['URL_Type_obf_Type'].value_counts()
# Out:
# URL_Type_obf_Type
# Defacement    7930
# benign        7781
# phishing      7586
# malware       6712
# spam          6698
# Name: count, dtype: int64

# %% [markdown]
# URL_Type_obf_Type
# Defacement    7930
# benign        7781
# phishing      7586
# malware       6712
# spam          6698
# Name: count, dtype: int64

# %%
df=dataset_1[dataset_1['URL_Type_obf_Type'] == 'Defacement']

# %%
df= dataset_1[(dataset_1['URL_Type_obf_Type'] == 'benign') | (dataset_1['URL_Type_obf_Type'] == 'phishing')]

# %%
df['URL_Type_obf_Type'].value_counts()
# Out:
# URL_Type_obf_Type
# benign      7781
# phishing    7586
# Name: count, dtype: int64

# %% [markdown]
# URL_Type_obf_Type
# benign      7781
# phishing    7586
# Name: count, dtype: int64

# %%
df.describe()
# Out:
# c:\Users\jryan\Documents\Red-Tape\red_tape_env\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#         Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# count  15367.000000        15367.000000      15367.000000       15367.000000
# mean       3.446021            2.543698          8.477061           5.851956
# std       14.151453            0.944938          4.660250           2.064581
# min        0.000000            2.000000          0.000000           1.500000
# 25%        0.000000            2.000000          5.000000           4.500000
# 50%        0.000000            2.000000          8.000000           5.500000
# 75%        0.000000            3.000000         11.000000           6.666666
# max      173.000000           19.000000         68.000000          29.500000
#
#        longdomaintokenlen  avgpathtokenlen           tld  charcompvowels  \
# ...

# %%
df.dtypes
# Out:
# Querylength                int64
# domain_token_count         int64
# path_token_count           int64
# avgdomaintokenlen        float64
# longdomaintokenlen         int64
#                           ...
# Entropy_DirectoryName    float64
# Entropy_Filename         float64
# Entropy_Extension        float64
# Entropy_Afterpath        float64
# URL_Type_obf_Type         object
# Length: 80, dtype: object

# %%
from scipy.stats import pointbiserialr
target=df["URL_Type_obf_Type"].map({"benign": 0, "phishing": 1})
corrs={}

for col in df.select_dtypes(include=['int64', 'float64']).columns:
    corrs[col]=pointbiserialr(df[col], target)[0]

import pandas as pd
import numpy as np

corr_df = pd.DataFrame.from_dict(corrs, orient='index', columns=['correlation'])
corr_df =corr_df.dropna()
threshold = 0.1
filtered_corr_df = corr_df[corr_df['correlation'].abs() >= threshold]
filtered_corr_df
# Out:
# c:\Users\jryan\Documents\Red-Tape\red_tape_env\Lib\site-packages\scipy\stats\_stats_py.py:4750: RuntimeWarning: invalid value encountered in subtract
#   xm = x - xmean
# c:\Users\jryan\Documents\Red-Tape\red_tape_env\Lib\site-packages\scipy\stats\_stats_py.py:5534: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rpb, prob = pearsonr(x, y)
#                                  correlation
# domain_token_count                  0.493899
# path_token_count                   -0.452085
# avgdomaintokenlen                   0.285330
# longdomaintokenlen                  0.409923
# tld                                 0.493899
# charcompvowels                     -0.362429
# charcompace                        -0.225861
# ldl_url                             0.251227
# ldl_path                            0.242006
# ldl_getArg                          0.111283
# dld_url                             0.206423
# ...
